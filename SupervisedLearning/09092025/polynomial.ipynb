# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import statistics as sts
import math as mts
from sklearn.preprocessing import StandardScaler,MinMaxScaler,PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,median_absolute_error,root_mean_squared_error,adjusted_rand_score

# %%
f1=pd.read_csv(r"polynomialdata.csv",encoding_errors='ignore')

# %%
f1.head(10)
# Out:
#       x     y
# 0  0.12  1.03
# 1  0.27  1.12
# 2  0.33  1.28
# 3  0.45  1.57
# 4  0.58  1.84
# 5  0.61  2.01
# 6  0.73  2.34
# 7  0.79  2.58
# 8  0.84  2.71
# 9  0.95  3.02

# %%
sns.set_style(style='dark')
plt.title("x and y VS Density",fontdict={'fontsize':20,'color':'black'})
sns.kdeplot(f1['x'],color='#ff8c00',fill='True')
plt.xlabel(' x- data and y -data',fontdict={'fontsize':20,'color':'green'})
sns.kdeplot(f1['y'],color='#000000',fill='True')
plt.ylabel('Density',fontdict={'fontsize':20,'color':'green'})
plt.show()

# %%
sns.set_style(style='dark')
plt.title("x and y VS Density",fontdict={'fontsize':20,'color':'black'})
plt.scatter(f1['x'],f1['y'],color='#ff8c00')
plt.xlabel(' x- data and y -data',fontdict={'fontsize':20,'color':'green'})
plt.ylabel('Density',fontdict={'fontsize':20,'color':'green'})
plt.show()

# %%
y=f1['y'].values.reshape(-1,1)
x=f1['x'].values.reshape(-1,1)

# %%
x
# Out:
# array([[0.12],
#        [0.27],
#        [0.33],
#        [0.45],
#        [0.58],
#        [0.61],
#        [0.73],
#        [0.79],
#        [0.84],
#        [0.95],
#        [1.02],
#        [1.15],
#        [1.23],
#        [1.34],
#        [1.41],
#        [1.52],
#        [1.6 ],
#        [1.73],
#        [1.81],
#        [1.94],
#        [2.01],
#        [2.13],
#        [2.22],
#        [2.35],
#        [2.41],
#        [2.53],
#        [2.6 ],
#        [2.74],
#        [2.81],
#        [2.93],
#        [3.02],
#        [3.15],
#        [3.22],
#        [3.34],
#        [3.41],
#        [3.53],
#        [3.6 ],
#        [3.73],
#        [3.81],
#        [3.94],
#        [4.01],
#        [4.13],
#        [4.22],
#        [4.35],
#        [4.41],
#        [4.53],
#        [4.6 ],
#        [4.74],
#        [4.81],
#        [4.93],
#        [5.02],
#        [5.15],
#        [5.22],
#        [5.34],
#        [5.41],
#        [5.53],
#        [5.6 ],
#        [5.73],
# ...

# %%
model_features=PolynomialFeatures(degree=2)
x_poly=model_features.fit_transform(y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,x_poly,test_size=0.2,random_state=42)

# %%
model_linear=LinearRegression()
model_linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model_linear.predict(x_test)
print(y_pred.round(2))
# Out:
# [[ 1.0000e+00 -1.0000e-02 -7.4600e+01]
#  [ 1.0000e+00  1.6900e+00 -3.8900e+01]
#  [ 1.0000e+00  1.5570e+01  2.5173e+02]
#  [ 1.0000e+00  1.0520e+01  1.4611e+02]
#  [ 1.0000e+00  4.2300e+00  1.4270e+01]
#  [ 1.0000e+00  1.8800e+01  3.1948e+02]
#  [ 1.0000e+00  1.1430e+01  1.6505e+02]
#  [ 1.0000e+00  1.6710e+01  2.7577e+02]
#  [ 1.0000e+00  3.8500e+00  6.2600e+00]
#  [ 1.0000e+00  1.3510e+01  2.0876e+02]
#  [ 1.0000e+00  1.1180e+01  1.5995e+02]
#  [ 1.0000e+00  2.0220e+01  3.4934e+02]
#  [ 1.0000e+00  5.1400e+00  3.3210e+01]]

# %%
#regression model metrics
print(mean_absolute_error(y_test,y_pred))
# Out:
# 10.560222627796842

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.9719213937998483

# %%
y_pred1=model_linear.predict([[2]])
print(y_pred1.round(2).tolist())
# Out:
# [[1.0, 6.53, 62.35]]
