# %%
from sklearn.datasets import make_classification,make_regression

# %%
x=make_regression(n_samples=100,n_features=)
x
# Out:
# (array([[-1.49076379e-01],
#         [-1.31595422e+00],
#         [-4.59238508e-01],
#         [ 1.29305118e+00],
#         [ 8.88187947e-01],
#         [-2.99132276e-01],
#         [-1.39232119e+00],
#         [-4.89747488e-01],
#         [-1.50915505e+00],
#         [ 6.83688502e-01],
#         [ 7.55511847e-01],
#         [ 4.12779652e-01],
#         [ 7.03893527e-01],
#         [-3.30437649e-02],
#         [ 5.86812123e-01],
#         [-9.84204956e-01],
#         [ 1.55580439e+00],
#         [ 8.80777280e-02],
#         [ 4.07918618e-01],
#         [-9.65655694e-02],
#         [-8.36295674e-01],
#         [-1.07497004e+00],
#         [-5.09103537e-01],
#         [ 1.06704501e-01],
#         [-7.54810040e-01],
#         [ 5.21950182e-03],
#         [-9.11027162e-01],
#         [ 5.41739994e-01],
#         [ 3.95487078e-01],
#         [-4.50460890e-02],
#         [ 3.94134757e-01],
#         [-7.57057655e-01],
#         [ 3.40434881e-01],
#         [ 5.54217994e-01],
# ...
