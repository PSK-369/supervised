# %%
import numpy as np
import statistics as sts

# %%
np.random.seed(42)
x=np.random.uniform(low=1,high=100,size=(100,1))
y=x+np.random.randint(low=100,high=1000,size=100)
print(f"{len(x)} and {(len(y))}")
# Out:
# 100 and 100
